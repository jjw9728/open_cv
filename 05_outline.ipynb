# %% [markdown]
# # 12. 윤곽선 검출

# %%
import cv as cv
siu = "imgs/BB.jpg"

# %%
img = cv.imread(siu)
img = cv.resize(img, (600, 400))
copied_img = img.copy()
copied_img_2 = img.copy()

gray = cv.cvtColor(copied_img, cv.COLOR_BGR2GRAY)
gray_2 = cv.cvtColor(copied_img_2, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
ret, otsu = cv.threshold(gray_2, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)

contours, hierachy = cv.findContours(otsu, cv.RETR_LIST, cv.CHAIN_APPROX_NONE)
contours_2, hierachy_2 = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

cv.drawContours(copied_img, contours, -1, (0, 0, 255), 2)
cv.drawContours(copied_img_2, contours_2, -1, (0, 0, 255), 2)

cv.imshow("list", copied_img)
cv.imshow("externel", copied_img_2)
# cv.imshow("origin", img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
img = cv.imread(siu)
img = cv.resize(img, (600, 400))
copied_img = img.copy()

gray = cv.cvtColor(copied_img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_LIST, cv.CHAIN_APPROX_NONE)

for cnt in contours:
    x, y, width, height = cv.boundingRect(cnt)
    

# cv.imshow("img", img)
cv.imshow("copy", copied_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv

img = cv.imread("images/vehicles.png")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

cv.namedWindow('img')
cv.createTrackbar('Index', 'img', 0, len(contours)-1, lambda x:x)

while True:    
    index = cv.getTrackbarPos('Index', 'img')
    copied_img = img.copy()
    
    x, y, width, height = cv.boundingRect(contours[index])
    cv.rectangle(copied_img, (x, y), (x + width, y + height), 
                (0, 255, 0), 2, cv.LINE_AA)

    cv.imshow('img', copied_img)
    if cv.waitKey(1) != -1:
        break

cv.destroyAllWindows()

# %%
import cv2 as cv

img = cv.imread("images/vehicles.png")
copied_img = img.copy()

gray = cv.cvtColor(copied_img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

for cnt in contours:
    if cv.contourArea(cnt) > 1000:
        x, y, width, height = cv.boundingRect(cnt)
        cv.rectangle(copied_img, (x, y), (x + width, y + height),
                 (0, 255, 0), 2, cv.LINE_AA)

cv.imshow('img', img)
cv.imshow('contour', copied_img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv

img = cv.imread("images/vehicles.png")
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

filtered_contours = [contour for contour in contours if cv.contourArea(contour) > 500]

# filtered_contours = []
# for contour in contours:
#     if cv.contourArea(contour) > 500:
#         filtered_contours.append(contour)

cv.namedWindow('img')
cv.createTrackbar('Index', 'img', 0, len(filtered_contours)-1, lambda x: x)

while True:
    index = cv.getTrackbarPos('Index', 'img')
    copied_img = img.copy()

    x, y, width, height = cv.boundingRect(filtered_contours[index])
    cv.rectangle(copied_img, (x, y), (x + width, y + height),
                 (0, 255, 0), 2, cv.LINE_AA)

    cv.imshow('img', copied_img)
    if cv.waitKey(1) != -1:
        break

cv.destroyAllWindows()

# %%
import cv2 as cv

img = cv.imread("images/playing_cards.png")
copied_img = img.copy()

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

filtered_contours = []
for contour in contours:
    if cv.contourArea(contour) > 500:
        filtered_contours.append(contour)
        
cv.imshow("contour", copied_img)

for i, cnt in enumerate(filtered_contours):
    x1, y1, width, height = cv.boundingRect(cnt)
    x2 = x1 + width
    y2 = y1 + height   
    seperated_img = img[y1:y2, x1:x2]  
    cv.imshow(f"CARD{i+1}", seperated_img)        

cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv

img = cv.imread("images/many_cards.png")


gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

filtered_contours = []
for contour in contours:
    if cv.contourArea(contour) > 30:
        filtered_contours.append(contour)

# print(len(filtered_contours))

cv.namedWindow('img')
cv.createTrackbar('Index', 'img', 0, len(filtered_contours)-1, lambda x: x)

while True:
    index = cv.getTrackbarPos('Index', 'img')
    copied_img = img.copy()
    x1, y1, width, height = cv.boundingRect(filtered_contours[index])
    x2 = x1 + width
    y2 = y1 + height   
    seperated_img = img[y1:y2, x1:x2]
     
    # cv.imshow(f"CARD{i+1}", seperated_img)        

cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 52

# %%
import cv2 as cv

img = cv.imread("images/many_cards.png")
copied_img = img.copy()

gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

filtered_contours = []
for contour in contours:
    if cv.contourArea(contour) > 30:
        filtered_contours.append(contour)
        
cv.imshow("contour", copied_img)

# for i, cnt in enumerate(filtered_contours):
#     x1, y1, width, height = cv.boundingRect(cnt)
#     x2 = x1 + width
#     y2 = y1 + height   
#     seperated_img = img[y1:y2, x1:x2]  
#     cv.imshow(f"CARD{i+1}", seperated_img)        

cv.waitKey(0)
cv.destroyAllWindows()

# %%
import cv2 as cv

img = cv.imread("images/many_cards.png")
img = cv.resize(img, (1200, 600))
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
ret, otsu = cv.threshold(gray, -1, 255, cv.THRESH_BINARY | cv.THRESH_OTSU)
contours, hierachy = cv.findContours(otsu, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

filtered_contours = []
for contour in contours:
    if cv.contourArea(contour) > 200:
        filtered_contours.append(contour)

cv.namedWindow('img')
cv.createTrackbar('Index', 'img', 0, len(filtered_contours) - 1, lambda x: x)

window_name = None
previous_index = -1  

cv.imshow('img', img)
while True:
    index = cv.getTrackbarPos('Index', 'img')
    copied_img = img.copy()
    x, y, width, height = cv.boundingRect(filtered_contours[index])
    cv.rectangle(copied_img, (x, y), (x + width, y + height),
                 (0, 0, 255), 5, cv.LINE_AA)       
    cv.imshow('img', copied_img)

    if index != previous_index:            
        x1, y1, width, height = cv.boundingRect(filtered_contours[index])
        x2 = x1 + width
        y2 = y1 + height
        separated_img = img[y1:y2, x1:x2]
        separated_img = cv.resize(separated_img, (150, 200))
        
        window_name = "CARD"
        
        cv.imshow(window_name, separated_img)        
        previous_index = index

    if cv.waitKey(1) != -1:
        break

cv.destroyAllWindows()
